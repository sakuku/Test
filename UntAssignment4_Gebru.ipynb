# %% [markdown]
# <a href="https://colab.research.google.com/github/sakuku/Test/blob/main/UntAssignment4_Gebru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = [
    {"name": "Alice", "score": 88},
    {"name": "Bob", "score": 54},
    {"name": "Charlie", "score": 92},
    {"name": "Diana", "score": 75},
    {"name": "Evan", "score": 48},
    {"name": "Fiona", "score": 81},
    {"name": "George", "score": 60}
]

# Initialize variables
total_score = 0
highest_score = 0
at_risk_students = []

# Loop through students
for student in students:
    score = student["score"]

# Add to total for average
    total_score += score

# Check for highest Score
    if score > highest_score:
      highest_score = score

# Check if student is at risk
    if score < 60:
       at_risk_students.append(student["name"])

# Calculate average
class_average = total_score /len(students)

# Print report
print("--------Class Report-----------")
print(f"Class Average: {clsas_average:.2f}")
print(f"Highest Score : {highest_score}")
print(f"Students At Risk: {at_risk_students}")
# Out:
# --------Class Report-----------
# Class Average: 71.14
# Highest Score : 92
# Students At Risk: ['Bob', 'Evan']
