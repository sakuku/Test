# %% [markdown]
# <a href="https://colab.research.google.com/github/sakuku/Test/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome to your first coding practice.
#
# This Jupyter Notebook contains the intructions for this ungraded assignment. Do not change the name for this file, and enter the variable names exactly as written in the instructions, otherwise your code will not run on Gradescope.
#
# To help you get familiar with Jupyter Notebooks as a coding environment, the first few sections of this file cover the basic organization and use of these files, and the practice questions follow.
#
# To ensure you have everything working properly, run the code in the code block below.
#
# To run the code, find the small circle with an arrowhead, like a "play" button, to the left of the code, and click it.

# %%
a = 5
print(a)
# Out:
# 5

# %% [markdown]
# If the code ran properly, you should see the number 5 displayed directly beneath that code block.
#
# In programming, displaying a number to a screen or other output source is referred to as printing. It does not mean to print it on paper using a laserjet or other type of printer.
#
# In the above code, the first line creates a new variable, which we are calling "a". Think of a variable as a container for data. In this case we put the number 5 in that container.
#
# When you see a name followed by parentheses, this is not a variable. It is a function. A function is what lets us reuse code without needing to re-type a long set of code each time. We give that code a name that we can use over and over. You can think of a function like a container for code, as opposed to a variable, which is a container for data.
#
# You can tell the difference because a function is followed by parenthesis. Often the parenthesis will contain data or variables. This is how we give the function the information we want it to process.
#
# In the above example, we are giving the variable "a" to the function "print()". "a" contains the number 5, so the function prints 5.

# %% [markdown]
# 1. Your first task is to to create a variable "a_plus_b". (Do not include the quotation marks in your variable name)

# %%
b = 7
a = 5
#put your code below here

print ( a+ b)

#print(a_plus_b)
# Out:
# 12

# %% [markdown]
# If you did this correctly, the value 12 should be printed below the code block.
#
# Notice how you did not need to tell Python what "a" was. In a Jupyter notebook, when you create a variable, it is available in other code blocks.
#
# You will want to remember that when you close your notebook, the next time you open the notebook, all variables will have been cleared. In that case, the varaible "a" doesn't exist unless you first run the code block where "a" is defined.

# %% [markdown]
# 2. Now, create a variable called "a_times_b"
#
# You should *assign* it the value that is the product of "a" and "b".
#
# Assign is the coding name for storing data in a variable. The single equals sign is the assignment operator: "="
#
# When you assign data to a variable, the variable name comes first, on the left of the "=" and the data or value is on the right side.
#
# After you write your code, run the code block.

# %%
# put your code here




#print(a_times_b)
print(a*b)
# Out:
# 35

# %% [markdown]
# If you properly created "a_times_b" you will see the answer 35 printed below the code.

# %% [markdown]
# 3. Now, create variables "number1" and "number2".
#
# Assign "number1" the value 4. Assign "number2" the value contained in "number1" times "*" 2.
#
# Finally, change "number1" by assigning it the values contained in "number2" divided by "/" the value currently in "number1".
#
# A variable can change its values, which is why it is called a variable. Notice how the value of "number1" is no longer 4.
#
# What value do you think "number1" should have at the end?
#
# And what about "number2"?

# %%
#put your code here
number1=4
number2=(number1 *2)


print(number1)

print(number2)
# Out:
# 4
# 8

# %% [markdown]
# I won't give you the answer. When you upload your code to Gradescope, the autograder will check your code to see if your answer is correct. You can check your answer there.
#
# The remaining problems will not show you the correct answer. Instead, you can check your answers by turning in this Jupyter Notebook.

# %% [markdown]
# 4. Create a variable that contains a *string*. A string is a variable that is a sequence of characters. A string is enclosed in quotation marks. This allows Python to distinguish it from a variable name.
#
# Create a variable "word1" and assign it the string "bye".
#
# Now create a variable, "doubleword" that contains the string "byebye", but do it by making use of the variable "word1", do not create the string "byebye" by hand. Hint: In Python, you can use mathematical operators on strings, just like you can on numbers.

# %%
#put your code here
word1="bye"
doubleword=(word1 *2)
print(doubleword)
# Out:
# byebye

# %% [markdown]
# 5. Now create a variable called "num_times" and give it the value 4.
#
# Then create a variable, "big_word", that repeats the string "hello" 8 times. But do so without explicitly typing the number 8.
#
# You have not been introduced to loops, so do this without using a loop.
#
# Hint: This requires you to make use of mathematical operators, like in prior questions.

# %%
#put your code here
num_times =4
big_word= ("hello" * num_times) *2
print(big_word)
# Out:
# hellohellohellohellohellohellohellohello

# %% [markdown]
# 6. Finally, create a variable called "my_name" and it should contain the string of your own name.
#
# Create a variable called "greeting" and assign it the string "Hello, " (notice the space!)
#
# Lastly, create a variable "greet_me". It should contain a string that is a greeting to you. If your name is Min, the variable should contain "Hello, Min".

# %%
#your code here
my_name="saba"
greet_me= f"hello {my_name}"
print(greet_me)
# Out:
# hello saba

# %% [markdown]
# This assignment has given you some experience working with variables and operators in Python. As you went through the assignment, you have discovered how the assignment operator works and how variables can change values. You know the difference between numeric values and strings.
#
# If you paid close attention, you should have also discovered how changing a variable affect other variables that were created using the first variable prior to its change.
